# %% [markdown]
# #

# %%
#importing necessary libraries
import pandas as pd
import numpy as np
from sklearn import linear_model
% matplotlib inline
import seaborn as sb

# %%
data = pd.read_csv('UCD1999-2015CSVDATA.csv')
data['Calculation'] = data['Deaths'] / data['Population'] * 100000
sorteddf = data.sort(['Calculation'], ascending=False)
sorteddf
# Out:
# //anaconda/lib/python3.5/site-packages/ipykernel/__main__.py:3: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   app.launch_new_instance()
#       Notes                                         ICDChapter ICDChapterCode  \
# 1501    NaN                 Diseases of the circulatory system        I00-I99
# 1497    NaN                 Diseases of the circulatory system        I00-I99
# 1500    NaN                 Diseases of the circulatory system        I00-I99
# 1496    NaN                 Diseases of the circulatory system        I00-I99
# 1499    NaN                 Diseases of the circulatory system        I00-I99
# 1495    NaN                 Diseases of the circulatory system        I00-I99
# 1498    NaN                 Diseases of the circulatory system        I00-I99
# 1494    NaN                 Diseases of the circulatory system        I00-I99
# 1446    NaN                                          Neoplasms        C00-D48
# ...

# %%
inputrace = input('Enter the race you would like to visualize (American Indian or Alaska Native, Asian or Pacific Islander, Black or African American, or White): '+ "\n" )
# Out:
# Enter the race you would like to visualize (American Indian or Alaska Native, Asian or Pacific Islander, Black or African American, or White):
# White

# %%
inputgender = input('Enter the gender you would like to visualize (Male or Female): '+ "\n" )
# Out:
# Enter the gender you would like to visualize (Male or Female):
# Male

# %%
inputdisease = input('Enter the the disease you want to visualize:'+ "\n" + "Diseases of the circulatory system" + "\n" + "Neoplasms" + "\n" + "Diseases of the respiratory system " + "\n" + "Diseases of the nervous system  " + "\n" + "Mental and behavioural disorders" + "\n" + "Certain conditions originating in the perinatal period" + "\n" + "Diseases of the genitourinary system" + "\n" + "Diseases of the genitourinary system" + "\n" + "Endocrine, nutritional and metabolic diseases" + "\n" + "External causes of morbidity and mortality " + "\n" + "Certain infectious and parasitic diseases" + "\n" + "Diseases of the digestive system" + "\n" + "Symptoms, signs and abnormal clinical and laboratory findings, not elsewhere classified" + "\n" + "Congenital malformations, deformations and chromosomal abnormalities" + "\n" + "Diseases of the musculoskeletal system and connective tissue" + "\n" + "Diseases of the skin and subcutaneous tissue" + "\n" + "Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism" + "\n" + "Pregnancy, childbirth and the puerperium" + "\n" + "Diseases of the ear and mastoid process" + "\n" + "Diseases of the eye and adnexa" + "\n" + "Codes for special purposes" + "\n"  )
# Out:
# Enter the the disease you want to visualize:
# Diseases of the circulatory system
# Neoplasms
# Diseases of the respiratory system
# Diseases of the nervous system
# Mental and behavioural disorders
# Certain conditions originating in the perinatal period
# Diseases of the genitourinary system
# Diseases of the genitourinary system
# Endocrine, nutritional and metabolic diseases
# External causes of morbidity and mortality
# Certain infectious and parasitic diseases
# Diseases of the digestive system
# Symptoms, signs and abnormal clinical and laboratory findings, not elsewhere classified
# Congenital malformations, deformations and chromosomal abnormalities
# Diseases of the musculoskeletal system and connective tissue
# Diseases of the skin and subcutaneous tissue
# Diseases of the blood and blood-forming organs and certain disorders involving the immune mechanism
# Pregnancy, childbirth and the puerperium
# Diseases of the ear and mastoid process
# Diseases of the eye and adnexa
# ...

# %%
uniquecategory = sorteddf[(sorteddf['Race'] == inputrace) & (sorteddf['Gender'] == inputgender) & (sorteddf['ICDChapter'] == inputdisease)]
uniquecategory
# Out:
#       Notes                          ICDChapter ICDChapterCode  \
# 1501    NaN  Diseases of the circulatory system        I00-I99
# 1357    NaN  Diseases of the circulatory system        I00-I99
# 1215    NaN  Diseases of the circulatory system        I00-I99
# 1068    NaN  Diseases of the circulatory system        I00-I99
# 922     NaN  Diseases of the circulatory system        I00-I99
# 773     NaN  Diseases of the circulatory system        I00-I99
# 65      NaN  Diseases of the circulatory system        I00-I99
# 624     NaN  Diseases of the circulatory system        I00-I99
# 478     NaN  Diseases of the circulatory system        I00-I99
# 197     NaN  Diseases of the circulatory system        I00-I99
# 333     NaN  Diseases of the circulatory system        I00-I99
#
#      Ten-Year Age Groups   Age Gender Gender Code   Race   Deaths  Population  \
# 1501           85+ years  85.0   Male           M  White  1703882    24932434
# ...

# %%
plt = uniquecategory.reset_index().plot.line(x = 'Age', y = 'Calculation')

plt.gca().invert_xaxis()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-bac882da9f0a> in <module>()
#       1 plt = uniquecategory.reset_index().plot.line(x = 'Age', y = 'Calculation')
#       2
# ----> 3 plt.gca().invert_xaxis()
#
# AttributeError: 'AxesSubplot' object has no attribute 'gca'

# %% [raw]
# #displaying the entire nation's coverage from 1995 to 2010 in a line graph
# EntireNation.reset_index().plot.line(x = 'Year', y = 'Yes_float')
#
# #had to reverse or "invert" x-axis
# plt.gca().invert_xaxis()
# `
# #plt.xticks(np.arange(min(x), max(x)+1, 1.0))

# %%
years = list(range(100))

# %%
data.plot.line(x = years, y = '' )
